# %%
# Imports

import plotly
import optuna
import mlflow
import dagshub
import mlflow.sklearn

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from imblearn.under_sampling import RandomUnderSampler
from gensim.models import Word2Vec
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Setting up DagsHub

dagshub.init(repo_owner='SushrutGaikwad', repo_name='youtube-comments-analyzer', mlflow=True)
# Out:
# Accessing as SushrutGaikwad
# Initialized MLflow to track repo "SushrutGaikwad/youtube-comments-analyzer"
# Repository SushrutGaikwad/youtube-comments-analyzer initialized!

# %% [markdown]
# # Data

# %%
PREPROCESSED_DATA_PATH = "../data/processed/reddit_preprocessed.csv"
df = pd.read_csv(PREPROCESSED_DATA_PATH)
df.dropna(subset=["clean_comment"], inplace=True)
df.shape
# Out:
# (36662, 2)

# %% [markdown]
# # Running the experiment

# %%
# Setting experiment name

mlflow.set_experiment("Improving LightGBM")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/eb66f0b362cf4a6e9e8119850de3216b', creation_time=1749135817604, experiment_id='7', last_update_time=1749135817604, lifecycle_stage='active', name='Improving LightGBM', tags={}>

# %% [markdown]
# ## Preprocessing

# %%
# Remapping class labels from {-1, 0, 1} to {2, 0, 1}
mapping = {
    -1: 2,
    0: 0,
    1: 1
}
df["category"] = df["category"].map(mapping)

# Removing missing sentiments
df.dropna(subset=["category"], inplace=True)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    df["clean_comment"],
    df["category"],
    test_size=0.2,
    random_state=42,
    stratify=df["category"]
)

# %%
X_train_tokenized = [sentence.split() for sentence in X_train]
X_test_tokenized = [sentence.split() for sentence in X_test]

# %%
# Word2Vec
word2vec_model = Word2Vec(
    sentences=X_train_tokenized,
    vector_size=300,
    window=5,
    min_count=1,
    workers=4,
    sg=1  # Skip-Gram model
)

# Generating vector representation for each comment
def vectorize_comments(tokenized_comments, word2vec_model):
    vectorized_comments = []
    for tokens in tokenized_comments:
        vectors = [word2vec_model.wv[token] for token in tokens if token in word2vec_model.wv]
        if len(vectors) > 0:
            vectorized_comments.append(np.mean(vectors, axis=0))
        else:
            vectorized_comments.append(np.zeros(word2vec_model.vector_size))
    return np.array(vectorized_comments)

# Vectorizing train and test comments
X_train_word2vec = vectorize_comments(X_train_tokenized, word2vec_model)
X_test_word2vec = vectorize_comments(X_test_tokenized, word2vec_model)

# %%
# Encoding the target labels
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Undersampling
rus = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = rus.fit_resample(
    X_train_word2vec,
    y_train_encoded
)

# %%
def objective(trial):
    # Suggest hyperparameters to be tuned
    params = {
        "objective": "multiclass",
        "num_class": 3,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 1e-1),
        "min_child_samples": trial.suggest_int("min_child_samples", 10, 200),
        "max_depth": trial.suggest_int("max_depth", 3, 30),
        "n_estimators": trial.suggest_int("n_estimators", 50, 500),
        "metric": "multi_logloss",
        # "is_unbalance": True,
        # "class_weight": "balanced",
    }

    # Initialize the LightGBM model with suggested parameters
    model = LGBMClassifier(**params, random_state=42, n_jobs=-1)

    # Perform cross-validation to evaluate the model performance
    scores = cross_val_score(
        model,
        X_train_resampled,
        y_train_resampled,
        cv=3,
        scoring="accuracy",
        n_jobs=-1
    )

    # Return the mean accuracy score across folds
    return scores.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=40)
# Out:
# [I 2025-06-07 11:51:56,684] A new study created in memory with name: no-name-11854aba-c741-479d-a0e4-5fdc5b9384ce
# [I 2025-06-07 11:52:10,052] Trial 0 finished with value: 0.6217035465292513 and parameters: {'learning_rate': 0.019664387089061135, 'min_child_samples': 127, 'max_depth': 8, 'n_estimators': 323}. Best is trial 0 with value: 0.6217035465292513.
# [I 2025-06-07 11:52:21,249] Trial 1 finished with value: 0.6015459230069718 and parameters: {'learning_rate': 0.0175228709469025, 'min_child_samples': 60, 'max_depth': 25, 'n_estimators': 111}. Best is trial 0 with value: 0.6217035465292513.
# [I 2025-06-07 11:52:36,158] Trial 2 finished with value: 0.6131656057391129 and parameters: {'learning_rate': 0.011033343303859432, 'min_child_samples': 52, 'max_depth': 14, 'n_estimators': 304}. Best is trial 0 with value: 0.6217035465292513.
# [I 2025-06-07 11:52:53,369] Trial 3 finished with value: 0.6270081842982722 and parameters: {'learning_rate': 0.04685471095208119, 'min_child_samples': 42, 'max_depth': 24, 'n_estimators': 407}. Best is trial 3 with value: 0.6270081842982722.
# [I 2025-06-07 11:53:01,870] Trial 4 finished with value: 0.6014954026472669 and parameters: {'learning_rate': 0.00979679863838746, 'min_child_samples': 112, 'max_depth': 4, 'n_estimators': 477}. Best is trial 3 with value: 0.6270081842982722.
# [I 2025-06-07 11:53:18,651] Trial 5 finished with value: 0.6281701525714863 and parameters: {'learning_rate': 0.0752320420007654, 'min_child_samples': 199, 'max_depth': 21, 'n_estimators': 443}. Best is trial 5 with value: 0.6281701525714863.
# [I 2025-06-07 11:53:29,474] Trial 6 finished with value: 0.6245832070324341 and parameters: {'learning_rate': 0.06971310780704787, 'min_child_samples': 75, 'max_depth': 15, 'n_estimators': 240}. Best is trial 5 with value: 0.6281701525714863.
# [I 2025-06-07 11:53:47,870] Trial 7 finished with value: 0.6323128220672931 and parameters: {'learning_rate': 0.034049818087663164, 'min_child_samples': 168, 'max_depth': 12, 'n_estimators': 478}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:54:03,953] Trial 8 finished with value: 0.6275133878953217 and parameters: {'learning_rate': 0.08085257314712535, 'min_child_samples': 112, 'max_depth': 11, 'n_estimators': 421}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:54:18,769] Trial 9 finished with value: 0.6074062847327473 and parameters: {'learning_rate': 0.0078065104553859226, 'min_child_samples': 197, 'max_depth': 29, 'n_estimators': 332}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:54:20,980] Trial 10 finished with value: 0.602505809841366 and parameters: {'learning_rate': 0.04178066320806253, 'min_child_samples': 158, 'max_depth': 3, 'n_estimators': 184}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:54:39,428] Trial 11 finished with value: 0.6287763968879458 and parameters: {'learning_rate': 0.09952765240244046, 'min_child_samples': 200, 'max_depth': 20, 'n_estimators': 488}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:54:57,908] Trial 12 finished with value: 0.6310498130746691 and parameters: {'learning_rate': 0.09319275584266086, 'min_child_samples': 162, 'max_depth': 19, 'n_estimators': 495}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:55:12,756] Trial 13 finished with value: 0.63003940588057 and parameters: {'learning_rate': 0.03320217186037392, 'min_child_samples': 157, 'max_depth': 18, 'n_estimators': 379}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:55:29,930] Trial 14 finished with value: 0.6304940891179145 and parameters: {'learning_rate': 0.05793862792470558, 'min_child_samples': 155, 'max_depth': 10, 'n_estimators': 485}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:55:43,864] Trial 15 finished with value: 0.6254420531474184 and parameters: {'learning_rate': 0.09203349230545507, 'min_child_samples': 139, 'max_depth': 13, 'n_estimators': 371}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:55:47,038] Trial 16 finished with value: 0.6018995655249065 and parameters: {'learning_rate': 0.03050718229940526, 'min_child_samples': 10, 'max_depth': 17, 'n_estimators': 56}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:55:54,635] Trial 17 finished with value: 0.6278670304132565 and parameters: {'learning_rate': 0.0626091060203491, 'min_child_samples': 164, 'max_depth': 8, 'n_estimators': 217}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:56:11,836] Trial 18 finished with value: 0.6286753561685359 and parameters: {'learning_rate': 0.03427537596822394, 'min_child_samples': 178, 'max_depth': 30, 'n_estimators': 442}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:56:31,402] Trial 19 finished with value: 0.6288269172476508 and parameters: {'learning_rate': 0.05587810613407083, 'min_child_samples': 94, 'max_depth': 23, 'n_estimators': 498}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:56:45,603] Trial 20 finished with value: 0.6275133878953219 and parameters: {'learning_rate': 0.08571580745764841, 'min_child_samples': 178, 'max_depth': 19, 'n_estimators': 374}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:57:01,735] Trial 21 finished with value: 0.6304435687582095 and parameters: {'learning_rate': 0.05348538488322113, 'min_child_samples': 142, 'max_depth': 10, 'n_estimators': 458}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:57:19,310] Trial 22 finished with value: 0.6294331615641103 and parameters: {'learning_rate': 0.06434423381150259, 'min_child_samples': 179, 'max_depth': 12, 'n_estimators': 500}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:57:32,331] Trial 23 finished with value: 0.6247347681115489 and parameters: {'learning_rate': 0.023148230846123878, 'min_child_samples': 153, 'max_depth': 7, 'n_estimators': 406}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:57:50,244] Trial 24 finished with value: 0.6293826412044053 and parameters: {'learning_rate': 0.04379852009034998, 'min_child_samples': 130, 'max_depth': 16, 'n_estimators': 457}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:58:04,804] Trial 25 finished with value: 0.5786096797009194 and parameters: {'learning_rate': 0.0013946715132948095, 'min_child_samples': 170, 'max_depth': 6, 'n_estimators': 424}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:58:18,115] Trial 26 finished with value: 0.6281701525714863 and parameters: {'learning_rate': 0.09989974962105205, 'min_child_samples': 95, 'max_depth': 10, 'n_estimators': 354}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:58:29,404] Trial 27 finished with value: 0.6270081842982722 and parameters: {'learning_rate': 0.0598335952440357, 'min_child_samples': 142, 'max_depth': 14, 'n_estimators': 287}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:58:46,991] Trial 28 finished with value: 0.628624835808831 and parameters: {'learning_rate': 0.07310586376533962, 'min_child_samples': 184, 'max_depth': 27, 'n_estimators': 472}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:58:59,377] Trial 29 finished with value: 0.6251894513488936 and parameters: {'learning_rate': 0.02416836503750605, 'min_child_samples': 124, 'max_depth': 9, 'n_estimators': 328}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:59:03,573] Trial 30 finished with value: 0.6171061937960999 and parameters: {'learning_rate': 0.04108232137908621, 'min_child_samples': 150, 'max_depth': 5, 'n_estimators': 162}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:59:19,808] Trial 31 finished with value: 0.6289279579670608 and parameters: {'learning_rate': 0.05374378396130347, 'min_child_samples': 140, 'max_depth': 11, 'n_estimators': 464}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:59:35,348] Trial 32 finished with value: 0.6319086591896534 and parameters: {'learning_rate': 0.05057014103356613, 'min_child_samples': 130, 'max_depth': 9, 'n_estimators': 433}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 11:59:50,541] Trial 33 finished with value: 0.6304940891179146 and parameters: {'learning_rate': 0.04837419407540139, 'min_child_samples': 120, 'max_depth': 13, 'n_estimators': 399}. Best is trial 7 with value: 0.6323128220672931.
# [I 2025-06-07 12:00:06,446] Trial 34 finished with value: 0.6329695867434576 and parameters: {'learning_rate': 0.04856071825064453, 'min_child_samples': 126, 'max_depth': 13, 'n_estimators': 411}. Best is trial 34 with value: 0.6329695867434576.
# [I 2025-06-07 12:00:23,558] Trial 35 finished with value: 0.6275639082550267 and parameters: {'learning_rate': 0.036888001216106234, 'min_child_samples': 100, 'max_depth': 22, 'n_estimators': 432}. Best is trial 34 with value: 0.6329695867434576.
# [I 2025-06-07 12:00:41,334] Trial 36 finished with value: 0.6230675962412852 and parameters: {'learning_rate': 0.017947373850474152, 'min_child_samples': 76, 'max_depth': 15, 'n_estimators': 397}. Best is trial 34 with value: 0.6329695867434576.
# [I 2025-06-07 12:00:54,602] Trial 37 finished with value: 0.6257956956653531 and parameters: {'learning_rate': 0.06738187007697652, 'min_child_samples': 111, 'max_depth': 18, 'n_estimators': 349}. Best is trial 34 with value: 0.6329695867434576.
# [I 2025-06-07 12:01:05,622] Trial 38 finished with value: 0.6241285237950893 and parameters: {'learning_rate': 0.02770110844540723, 'min_child_samples': 129, 'max_depth': 8, 'n_estimators': 303}. Best is trial 34 with value: 0.6329695867434576.
# [I 2025-06-07 12:01:22,068] Trial 39 finished with value: 0.6290289986864707 and parameters: {'learning_rate': 0.08051472571349327, 'min_child_samples': 82, 'max_depth': 12, 'n_estimators': 447}. Best is trial 34 with value: 0.6329695867434576.

# %%
best_params = study.best_trial.params
best_params
# Out:
# {'learning_rate': 0.04856071825064453,
#  'min_child_samples': 126,
#  'max_depth': 13,
#  'n_estimators': 411}

# %%
best_model = LGBMClassifier(
    objective="multiclass",
    num_class=3,
    metric="multi_logloss",
    # is_unbalance=True,
    # class_weight="balanced",
    learning_rate=best_params["learning_rate"],
    max_depth=best_params["max_depth"],
    n_estimators=best_params["n_estimators"],
    min_child_samples=best_params["min_child_samples"],
    random_state=42,
    n_jobs=-1
)

# %%
best_model.fit(X_train_resampled, y_train_resampled)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015690 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 19794, number of used features: 300
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMClassifier(learning_rate=0.04856071825064453, max_depth=13,
#                metric='multi_logloss', min_child_samples=126, n_estimators=411,
#                n_jobs=-1, num_class=3, objective='multiclass', random_state=42)

# %%
y_train_pred = best_model.predict(X_train_resampled)
accuracy_train = accuracy_score(
    y_true=y_train_resampled,
    y_pred=y_train_pred
)
accuracy_train
# Out:
# d:\projects\DSMP2_p2\youtube-comments-analyzer\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 0.9546327169849449

# %%
classification_report_train = classification_report(
    y_true=y_train_resampled,
    y_pred=y_train_pred
)
print(classification_report_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      6598
#            1       0.95      0.95      0.95      6598
#            2       0.95      0.95      0.95      6598
#
#     accuracy                           0.95     19794
#    macro avg       0.95      0.95      0.95     19794
# weighted avg       0.95      0.95      0.95     19794

# %%
# Make predictions on the test data
y_test_pred = best_model.predict(X_test_word2vec)
accuracy_test = accuracy_score(
    y_true=y_test_encoded,
    y_pred=y_test_pred
)
accuracy_test
# Out:
# d:\projects\DSMP2_p2\youtube-comments-analyzer\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 0.6463930178644484

# %%
classification_report_test = classification_report(
    y_true=y_test_encoded,
    y_pred=y_test_pred
)
print(classification_report_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.74      2529
#            1       0.72      0.63      0.67      3154
#            2       0.44      0.56      0.49      1650
#
#     accuracy                           0.65      7333
#    macro avg       0.63      0.64      0.63      7333
# weighted avg       0.67      0.65      0.65      7333

# %%
# Function to log results to MLFlow
def log_to_mlflow(
    model_name,
    improvement_technique,
    model,
    X_train,
    X_test,
    y_train,
    y_test,
    best_params
):
    with mlflow.start_run():
        # Tags
        mlflow.set_tag(
            "mlflow.runName", f"{model_name}_{improvement_technique}"
        )
        mlflow.set_tag("experiment_type", "Improving LightGBM")
        
        # Logging improvement technique as a parameter
        mlflow.log_param("improvement_technique", improvement_technique)
        
        # Initializing and training the model
        model.fit(X_train, y_train)
        
        # Making predictions on the test set and logging metrics
        y_pred = model.predict(X_test)
        
        # Logging cross-val accuracy
        scores = cross_val_score(
            model,
            X_train,
            y_train,
            cv=3,
            scoring="accuracy",
            n_jobs=-1
        )
        mlflow.log_metric("cross_val_accuracy", scores.mean())
        
        # Logging accuracy
        accuracy = accuracy_score(
            y_true=y_test,
            y_pred=y_pred
        )
        mlflow.log_metric("test_accuracy", accuracy)
        
        # Logging classification report metrics
        classification_rep = classification_report(
            y_true=y_test,
            y_pred=y_pred,
            output_dict=True
        )
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}: {metric} - test", value)
        
        # Logging the model
        mlflow.sklearn.log_model(model, f"{model_name}_model")
        
        # Logging the best parameters
        mlflow.log_params(best_params)

# %%
log_to_mlflow(
    model_name="LightGBM",
    improvement_technique="word2vec",
    model=best_model,
    X_train=X_train_resampled,
    X_test=X_test_word2vec,
    y_train=y_train_resampled,
    y_test=y_test_encoded,
    best_params=best_params
)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015081 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 19794, number of used features: 300
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# d:\projects\DSMP2_p2\youtube-comments-analyzer\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 2025/06/07 12:04:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run LightGBM_word2vec at: https://dagshub.com/SushrutGaikwad/youtube-comments-analyzer.mlflow/#/experiments/7/runs/df9e8ef9b1754c55962f70448bec9d82
# 🧪 View experiment at: https://dagshub.com/SushrutGaikwad/youtube-comments-analyzer.mlflow/#/experiments/7
