# %%
# Imports

import plotly
import optuna
import mlflow
import dagshub
import mlflow.sklearn

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from imblearn.under_sampling import RandomUnderSampler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, cross_val_score
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Setting up DagsHub

dagshub.init(repo_owner='SushrutGaikwad', repo_name='youtube-comments-analyzer', mlflow=True)
# Out:
# Accessing as SushrutGaikwad
# Initialized MLflow to track repo "SushrutGaikwad/youtube-comments-analyzer"
# Repository SushrutGaikwad/youtube-comments-analyzer initialized!

# %% [markdown]
# # Data

# %%
PREPROCESSED_DATA_PATH = "../data/processed/reddit_preprocessed.csv"
df = pd.read_csv(PREPROCESSED_DATA_PATH)
df.dropna(subset=["clean_comment"], inplace=True)
df.shape
# Out:
# (36662, 2)

# %% [markdown]
# # Running the experiment

# %%
# Setting experiment name

mlflow.set_experiment("Improving LightGBM")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/eb66f0b362cf4a6e9e8119850de3216b', creation_time=1749135817604, experiment_id='7', last_update_time=1749135817604, lifecycle_stage='active', name='Improving LightGBM', tags={}>

# %% [markdown]
# ## Preprocessing

# %%
# Remapping class labels from {-1, 0, 1} to {2, 0, 1}
mapping = {
    -1: 2,
    0: 0,
    1: 1
}
df["category"] = df["category"].map(mapping)

# Removing missing sentiments
df.dropna(subset=["category"], inplace=True)

# Feature engineering
ngram_range = (1, 2)
max_features = 1000
vectorizer = CountVectorizer(
    ngram_range=ngram_range,
    max_features=max_features
)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    df["clean_comment"],
    df["category"],
    test_size=0.2,
    random_state=42,
    stratify=df["category"]
)
X_train_vectorized = vectorizer.fit_transform(X_train)
X_test_vectorized = vectorizer.transform(X_test)

# # Undersampling
# rus = RandomUnderSampler(random_state=42)
# X_train_vectorized, y_train = rus.fit_resample(
#     X_train_vectorized,
#     y_train
# )

X_train_vectorized = X_train_vectorized.astype(np.float32)
X_test_vectorized = X_test_vectorized.astype(np.float32)

# %%
# Function to log results to MLFlow
def log_to_mlflow(
    model_name,
    improvement_technique,
    model,
    X_train,
    X_test,
    y_train,
    y_test,
    best_params
):
    with mlflow.start_run():
        # Tags
        mlflow.set_tag(
            "mlflow.runName", f"{model_name}_{improvement_technique}"
        )
        mlflow.set_tag("experiment_type", "Improving LightGBM")
        
        # Logging improvement technique as a parameter
        mlflow.log_param("improvement_technique", improvement_technique)
        
        # Initializing and training the model
        model.fit(X_train, y_train)
        
        # Making predictions on the test set and logging metrics
        y_pred = model.predict(X_test)
        
        # Logging cross-val accuracy
        scores = cross_val_score(
            model,
            X_train,
            y_train,
            cv=3,
            scoring="accuracy",
            n_jobs=-1
        )
        mlflow.log_metric("cross_val_accuracy", scores.mean())
        
        # Logging accuracy
        accuracy = accuracy_score(
            y_true=y_test,
            y_pred=y_pred
        )
        mlflow.log_metric("test_accuracy", accuracy)
        
        # Logging classification report metrics
        classification_rep = classification_report(
            y_true=y_test,
            y_pred=y_pred,
            output_dict=True
        )
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}: {metric} - test", value)
        
        # Logging the model
        mlflow.sklearn.log_model(model, f"{model_name}_model")
        
        # Logging the best parameters
        mlflow.log_params(best_params)

# %%
# Optuna objective function
def objective(trial):
    # Hyperparameter space
    params = {
        "objective": "multiclass",
        "num_class": 3,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 1e-1),
        "min_child_samples": trial.suggest_int("min_child_samples", 10, 200),
        "max_depth": trial.suggest_int("max_depth", 3, 30),
        "n_estimators": trial.suggest_int("n_estimators", 50, 500),
        "metric": "multi_logloss",
        "is_unbalance": True,
        "class_weight": "balanced",
    }

    # Define the LightGBM model with the trial parameters
    model = LGBMClassifier(**params, random_state=42, n_jobs=-1)

    # Performing cross-validation
    scores = cross_val_score(
        model,
        X_train_vectorized,
        y_train,
        cv=3,
        scoring="accuracy",
        n_jobs=-1
    )

    # Returning the average accuracy across folds
    return scores.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-06-05 23:30:28,438] A new study created in memory with name: no-name-731a2364-35b9-4540-81d6-ecd062264617
# [I 2025-06-05 23:30:30,919] Trial 0 finished with value: 0.6555968208340036 and parameters: {'learning_rate': 0.023564721504423045, 'min_child_samples': 180, 'max_depth': 9, 'n_estimators': 90}. Best is trial 0 with value: 0.6555968208340036.
# [I 2025-06-05 23:30:34,447] Trial 1 finished with value: 0.6726449426688698 and parameters: {'learning_rate': 0.02104596108908152, 'min_child_samples': 192, 'max_depth': 14, 'n_estimators': 184}. Best is trial 1 with value: 0.6726449426688698.
# [I 2025-06-05 23:30:47,300] Trial 2 finished with value: 0.7507245870975119 and parameters: {'learning_rate': 0.04381973759052136, 'min_child_samples': 101, 'max_depth': 22, 'n_estimators': 490}. Best is trial 2 with value: 0.7507245870975119.
# [I 2025-06-05 23:30:52,594] Trial 3 finished with value: 0.6832147603505806 and parameters: {'learning_rate': 0.058129634987198836, 'min_child_samples': 197, 'max_depth': 22, 'n_estimators': 220}. Best is trial 2 with value: 0.7507245870975119.
# [I 2025-06-05 23:30:55,930] Trial 4 finished with value: 0.705888312226815 and parameters: {'learning_rate': 0.05726344678194991, 'min_child_samples': 148, 'max_depth': 16, 'n_estimators': 145}. Best is trial 2 with value: 0.7507245870975119.
# [I 2025-06-05 23:31:03,273] Trial 5 finished with value: 0.7100822182180352 and parameters: {'learning_rate': 0.013956869492545619, 'min_child_samples': 135, 'max_depth': 14, 'n_estimators': 431}. Best is trial 2 with value: 0.7507245870975119.
# [I 2025-06-05 23:31:13,275] Trial 6 finished with value: 0.7339153054467601 and parameters: {'learning_rate': 0.028139927840260755, 'min_child_samples': 117, 'max_depth': 22, 'n_estimators': 433}. Best is trial 2 with value: 0.7507245870975119.
# [I 2025-06-05 23:31:23,293] Trial 7 finished with value: 0.6966143590446666 and parameters: {'learning_rate': 0.06357277497634449, 'min_child_samples': 179, 'max_depth': 24, 'n_estimators': 435}. Best is trial 2 with value: 0.7507245870975119.
# [I 2025-06-05 23:31:27,085] Trial 8 finished with value: 0.7179584026853943 and parameters: {'learning_rate': 0.03985803850140464, 'min_child_samples': 132, 'max_depth': 17, 'n_estimators': 216}. Best is trial 2 with value: 0.7507245870975119.
# [I 2025-06-05 23:31:30,491] Trial 9 finished with value: 0.7001603711484042 and parameters: {'learning_rate': 0.0980786403540605, 'min_child_samples': 167, 'max_depth': 8, 'n_estimators': 405}. Best is trial 2 with value: 0.7507245870975119.
# [I 2025-06-05 23:31:40,537] Trial 10 finished with value: 0.7819224440148983 and parameters: {'learning_rate': 0.08354566081121406, 'min_child_samples': 61, 'max_depth': 30, 'n_estimators': 344}. Best is trial 10 with value: 0.7819224440148983.
# [I 2025-06-05 23:31:49,853] Trial 11 finished with value: 0.7822292517298327 and parameters: {'learning_rate': 0.08237205508376165, 'min_child_samples': 59, 'max_depth': 30, 'n_estimators': 324}. Best is trial 11 with value: 0.7822292517298327.
# [I 2025-06-05 23:31:59,133] Trial 12 finished with value: 0.7855706253824722 and parameters: {'learning_rate': 0.0842216328201255, 'min_child_samples': 47, 'max_depth': 30, 'n_estimators': 322}. Best is trial 12 with value: 0.7855706253824722.
# [I 2025-06-05 23:32:07,602] Trial 13 finished with value: 0.7951516059909021 and parameters: {'learning_rate': 0.07978450752069104, 'min_child_samples': 14, 'max_depth': 30, 'n_estimators': 298}. Best is trial 13 with value: 0.7951516059909021.
# [I 2025-06-05 23:32:16,071] Trial 14 finished with value: 0.7960040232425869 and parameters: {'learning_rate': 0.08198686735005632, 'min_child_samples': 12, 'max_depth': 27, 'n_estimators': 297}. Best is trial 14 with value: 0.7960040232425869.
# [I 2025-06-05 23:32:23,753] Trial 15 finished with value: 0.7943332963102275 and parameters: {'learning_rate': 0.07429618066044114, 'min_child_samples': 22, 'max_depth': 26, 'n_estimators': 257}. Best is trial 14 with value: 0.7960040232425869.
# [I 2025-06-05 23:32:32,204] Trial 16 finished with value: 0.796004044167477 and parameters: {'learning_rate': 0.09957494957429788, 'min_child_samples': 11, 'max_depth': 26, 'n_estimators': 282}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:32:43,430] Trial 17 finished with value: 0.7630332736164868 and parameters: {'learning_rate': 0.09844026514258405, 'min_child_samples': 87, 'max_depth': 26, 'n_estimators': 382}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:32:45,662] Trial 18 finished with value: 0.7746258441309952 and parameters: {'learning_rate': 0.0923102968795564, 'min_child_samples': 34, 'max_depth': 4, 'n_estimators': 260}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:32:47,765] Trial 19 finished with value: 0.6689624130940487 and parameters: {'learning_rate': 0.0031652532228900465, 'min_child_samples': 84, 'max_depth': 18, 'n_estimators': 68}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:32:51,679] Trial 20 finished with value: 0.794299227101516 and parameters: {'learning_rate': 0.06823184037039078, 'min_child_samples': 10, 'max_depth': 26, 'n_estimators': 125}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:33:00,980] Trial 21 finished with value: 0.795594875377213 and parameters: {'learning_rate': 0.07544687451970886, 'min_child_samples': 14, 'max_depth': 27, 'n_estimators': 310}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:33:09,350] Trial 22 finished with value: 0.7883324249141005 and parameters: {'learning_rate': 0.08876591734657392, 'min_child_samples': 37, 'max_depth': 27, 'n_estimators': 282}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:33:19,744] Trial 23 finished with value: 0.7924580041638857 and parameters: {'learning_rate': 0.07403144420057789, 'min_child_samples': 25, 'max_depth': 20, 'n_estimators': 361}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:33:26,538] Trial 24 finished with value: 0.7846501045881812 and parameters: {'learning_rate': 0.09222749586114065, 'min_child_samples': 52, 'max_depth': 28, 'n_estimators': 229}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:33:34,943] Trial 25 finished with value: 0.7745576115515661 and parameters: {'learning_rate': 0.06834083080249198, 'min_child_samples': 70, 'max_depth': 23, 'n_estimators': 299}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:33:40,310] Trial 26 finished with value: 0.7904804346417751 and parameters: {'learning_rate': 0.09874487536428657, 'min_child_samples': 35, 'max_depth': 24, 'n_estimators': 178}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:33:48,060] Trial 27 finished with value: 0.7952198211329226 and parameters: {'learning_rate': 0.0756880829520043, 'min_child_samples': 22, 'max_depth': 20, 'n_estimators': 261}. Best is trial 16 with value: 0.796004044167477.
# [I 2025-06-05 23:33:58,957] Trial 28 finished with value: 0.7987316733534247 and parameters: {'learning_rate': 0.050202462501336045, 'min_child_samples': 10, 'max_depth': 28, 'n_estimators': 371}. Best is trial 28 with value: 0.7987316733534247.
# [I 2025-06-05 23:34:12,853] Trial 29 finished with value: 0.7871049429556803 and parameters: {'learning_rate': 0.04884450059369872, 'min_child_samples': 43, 'max_depth': 28, 'n_estimators': 480}. Best is trial 28 with value: 0.7987316733534247.
# [I 2025-06-05 23:34:22,313] Trial 30 finished with value: 0.7679089404299625 and parameters: {'learning_rate': 0.028825460384435116, 'min_child_samples': 75, 'max_depth': 20, 'n_estimators': 362}. Best is trial 28 with value: 0.7987316733534247.
# [I 2025-06-05 23:34:31,863] Trial 31 finished with value: 0.7962085954315329 and parameters: {'learning_rate': 0.054061681405544806, 'min_child_samples': 16, 'max_depth': 25, 'n_estimators': 325}. Best is trial 28 with value: 0.7987316733534247.
# [I 2025-06-05 23:34:43,328] Trial 32 finished with value: 0.7939923008122038 and parameters: {'learning_rate': 0.04234054222966334, 'min_child_samples': 27, 'max_depth': 25, 'n_estimators': 394}. Best is trial 28 with value: 0.7987316733534247.
# [I 2025-06-05 23:34:54,178] Trial 33 finished with value: 0.7987657774369531 and parameters: {'learning_rate': 0.035382561922754754, 'min_child_samples': 10, 'max_depth': 28, 'n_estimators': 373}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:35:04,315] Trial 34 finished with value: 0.7943673515690124 and parameters: {'learning_rate': 0.036055065728766655, 'min_child_samples': 29, 'max_depth': 28, 'n_estimators': 346}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:35:16,978] Trial 35 finished with value: 0.7976746839127937 and parameters: {'learning_rate': 0.05053718904095429, 'min_child_samples': 10, 'max_depth': 11, 'n_estimators': 465}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:35:26,519] Trial 36 finished with value: 0.7849909570994553 and parameters: {'learning_rate': 0.051493160860484256, 'min_child_samples': 46, 'max_depth': 11, 'n_estimators': 487}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:35:37,892] Trial 37 finished with value: 0.7938218571191582 and parameters: {'learning_rate': 0.054969373610898146, 'min_child_samples': 22, 'max_depth': 10, 'n_estimators': 467}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:35:48,472] Trial 38 finished with value: 0.7892530154580255 and parameters: {'learning_rate': 0.04809362021192592, 'min_child_samples': 34, 'max_depth': 13, 'n_estimators': 452}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:35:54,080] Trial 39 finished with value: 0.7738757530798229 and parameters: {'learning_rate': 0.0348009680781754, 'min_child_samples': 40, 'max_depth': 7, 'n_estimators': 413}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:36:00,676] Trial 40 finished with value: 0.7438030240204906 and parameters: {'learning_rate': 0.06161880754616595, 'min_child_samples': 105, 'max_depth': 15, 'n_estimators': 380}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:36:12,698] Trial 41 finished with value: 0.7937536942893632 and parameters: {'learning_rate': 0.01951289781341559, 'min_child_samples': 12, 'max_depth': 24, 'n_estimators': 425}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:36:22,397] Trial 42 finished with value: 0.797026863262427 and parameters: {'learning_rate': 0.04569035085703416, 'min_child_samples': 19, 'max_depth': 22, 'n_estimators': 337}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:36:32,445] Trial 43 finished with value: 0.7968222736360725 and parameters: {'learning_rate': 0.045193492925190454, 'min_child_samples': 20, 'max_depth': 22, 'n_estimators': 342}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:36:41,096] Trial 44 finished with value: 0.7822973936347376 and parameters: {'learning_rate': 0.04521472293435405, 'min_child_samples': 56, 'max_depth': 18, 'n_estimators': 350}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:36:48,309] Trial 45 finished with value: 0.7066384137404323 and parameters: {'learning_rate': 0.03726160150867959, 'min_child_samples': 152, 'max_depth': 21, 'n_estimators': 377}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:36:53,537] Trial 46 finished with value: 0.7613284739879341 and parameters: {'learning_rate': 0.03025932688641747, 'min_child_samples': 28, 'max_depth': 5, 'n_estimators': 454}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:37:00,024] Trial 47 finished with value: 0.7348699930992503 and parameters: {'learning_rate': 0.05919000956357132, 'min_child_samples': 117, 'max_depth': 16, 'n_estimators': 405}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:37:13,663] Trial 48 finished with value: 0.795560774781166 and parameters: {'learning_rate': 0.042316408624884456, 'min_child_samples': 18, 'max_depth': 23, 'n_estimators': 500}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:37:19,829] Trial 49 finished with value: 0.7602373490764395 and parameters: {'learning_rate': 0.02293437751322791, 'min_child_samples': 68, 'max_depth': 12, 'n_estimators': 331}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:37:31,708] Trial 50 finished with value: 0.7857411527750785 and parameters: {'learning_rate': 0.04583152602610145, 'min_child_samples': 49, 'max_depth': 29, 'n_estimators': 436}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:37:41,326] Trial 51 finished with value: 0.7969245928616214 and parameters: {'learning_rate': 0.05403806247697286, 'min_child_samples': 16, 'max_depth': 22, 'n_estimators': 338}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:37:50,905] Trial 52 finished with value: 0.7921511092619088 and parameters: {'learning_rate': 0.05062966469643614, 'min_child_samples': 30, 'max_depth': 22, 'n_estimators': 369}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:38:01,259] Trial 53 finished with value: 0.7951857170493941 and parameters: {'learning_rate': 0.03309189257654119, 'min_child_samples': 19, 'max_depth': 17, 'n_estimators': 396}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:38:10,699] Trial 54 finished with value: 0.7971973278803627 and parameters: {'learning_rate': 0.039544226853071386, 'min_child_samples': 21, 'max_depth': 21, 'n_estimators': 348}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:38:15,933] Trial 55 finished with value: 0.6874426727758417 and parameters: {'learning_rate': 0.04037426299647448, 'min_child_samples': 185, 'max_depth': 19, 'n_estimators': 308}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:38:27,688] Trial 56 finished with value: 0.7882641923346715 and parameters: {'learning_rate': 0.05393964626770694, 'min_child_samples': 39, 'max_depth': 23, 'n_estimators': 416}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:38:36,730] Trial 57 finished with value: 0.7910259779163731 and parameters: {'learning_rate': 0.065521318805235, 'min_child_samples': 30, 'max_depth': 21, 'n_estimators': 333}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:38:46,067] Trial 58 finished with value: 0.7582598458164811 and parameters: {'learning_rate': 0.01904002486557534, 'min_child_samples': 11, 'max_depth': 8, 'n_estimators': 394}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:38:52,854] Trial 59 finished with value: 0.797947509606059 and parameters: {'learning_rate': 0.05769440944221179, 'min_child_samples': 10, 'max_depth': 29, 'n_estimators': 235}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:38:58,235] Trial 60 finished with value: 0.7937195518435359 and parameters: {'learning_rate': 0.038862411511126696, 'min_child_samples': 23, 'max_depth': 29, 'n_estimators': 204}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:39:04,372] Trial 61 finished with value: 0.7985953267689442 and parameters: {'learning_rate': 0.05881496408870392, 'min_child_samples': 11, 'max_depth': 30, 'n_estimators': 237}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:39:11,207] Trial 62 finished with value: 0.797367834348079 and parameters: {'learning_rate': 0.0595950684599411, 'min_child_samples': 11, 'max_depth': 29, 'n_estimators': 239}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:39:17,955] Trial 63 finished with value: 0.7973678378355608 and parameters: {'learning_rate': 0.06286151772882426, 'min_child_samples': 10, 'max_depth': 29, 'n_estimators': 233}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:39:24,227] Trial 64 finished with value: 0.7984589348472017 and parameters: {'learning_rate': 0.058975948504553004, 'min_child_samples': 10, 'max_depth': 29, 'n_estimators': 236}. Best is trial 33 with value: 0.7987657774369531.
# [I 2025-06-05 23:39:31,194] Trial 65 finished with value: 0.7989362978545961 and parameters: {'learning_rate': 0.06747064968662127, 'min_child_samples': 10, 'max_depth': 30, 'n_estimators': 240}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:39:36,098] Trial 66 finished with value: 0.7923216122421434 and parameters: {'learning_rate': 0.07058472124870456, 'min_child_samples': 33, 'max_depth': 30, 'n_estimators': 183}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:39:41,662] Trial 67 finished with value: 0.7949129332059092 and parameters: {'learning_rate': 0.06557557956307554, 'min_child_samples': 24, 'max_depth': 27, 'n_estimators': 212}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:39:46,256] Trial 68 finished with value: 0.7955948439898778 and parameters: {'learning_rate': 0.05657958973833858, 'min_child_samples': 16, 'max_depth': 28, 'n_estimators': 162}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:39:52,801] Trial 69 finished with value: 0.787855006106999 and parameters: {'learning_rate': 0.07126603653876379, 'min_child_samples': 41, 'max_depth': 30, 'n_estimators': 256}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:39:57,860] Trial 70 finished with value: 0.7939922973247221 and parameters: {'learning_rate': 0.07823790285815235, 'min_child_samples': 25, 'max_depth': 27, 'n_estimators': 196}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:40:03,902] Trial 71 finished with value: 0.7987316803283879 and parameters: {'learning_rate': 0.06309994732388015, 'min_child_samples': 11, 'max_depth': 29, 'n_estimators': 235}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:40:11,169] Trial 72 finished with value: 0.7986635209860746 and parameters: {'learning_rate': 0.060003623220622665, 'min_child_samples': 10, 'max_depth': 29, 'n_estimators': 271}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:40:18,315] Trial 73 finished with value: 0.7967540584940519 and parameters: {'learning_rate': 0.061073132029322796, 'min_child_samples': 16, 'max_depth': 28, 'n_estimators': 246}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:40:25,629] Trial 74 finished with value: 0.7928671450542962 and parameters: {'learning_rate': 0.06521231177688401, 'min_child_samples': 27, 'max_depth': 29, 'n_estimators': 285}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:40:32,982] Trial 75 finished with value: 0.7982884527918576 and parameters: {'learning_rate': 0.056714630990252216, 'min_child_samples': 10, 'max_depth': 30, 'n_estimators': 272}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:40:40,452] Trial 76 finished with value: 0.7965836008510795 and parameters: {'learning_rate': 0.06872230723932554, 'min_child_samples': 16, 'max_depth': 30, 'n_estimators': 275}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:40:47,972] Trial 77 finished with value: 0.7576120391160411 and parameters: {'learning_rate': 0.009817669101365913, 'min_child_samples': 35, 'max_depth': 25, 'n_estimators': 271}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:40:54,281] Trial 78 finished with value: 0.7954925491767004 and parameters: {'learning_rate': 0.0727140391761954, 'min_child_samples': 21, 'max_depth': 26, 'n_estimators': 221}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:41:01,399] Trial 79 finished with value: 0.790480389304513 and parameters: {'learning_rate': 0.06379234023839375, 'min_child_samples': 32, 'max_depth': 27, 'n_estimators': 249}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:41:09,011] Trial 80 finished with value: 0.7970950714294842 and parameters: {'learning_rate': 0.056192766747825605, 'min_child_samples': 15, 'max_depth': 30, 'n_estimators': 265}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:41:15,568] Trial 81 finished with value: 0.7980498009317546 and parameters: {'learning_rate': 0.05862382956453082, 'min_child_samples': 10, 'max_depth': 28, 'n_estimators': 229}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:41:20,081] Trial 82 finished with value: 0.6823282250654406 and parameters: {'learning_rate': 0.052583906447104034, 'min_child_samples': 199, 'max_depth': 28, 'n_estimators': 221}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:41:28,022] Trial 83 finished with value: 0.7946060627163041 and parameters: {'learning_rate': 0.060236995542462035, 'min_child_samples': 26, 'max_depth': 30, 'n_estimators': 292}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:41:33,723] Trial 84 finished with value: 0.7969246242489568 and parameters: {'learning_rate': 0.06694539228840296, 'min_child_samples': 15, 'max_depth': 28, 'n_estimators': 196}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:41:38,110] Trial 85 finished with value: 0.7945037713906085 and parameters: {'learning_rate': 0.04881217338756263, 'min_child_samples': 20, 'max_depth': 26, 'n_estimators': 164}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:41:46,165] Trial 86 finished with value: 0.7593509393406405 and parameters: {'learning_rate': 0.058391878386046724, 'min_child_samples': 93, 'max_depth': 29, 'n_estimators': 311}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:41:53,231] Trial 87 finished with value: 0.7988680478377587 and parameters: {'learning_rate': 0.06244876809060328, 'min_child_samples': 10, 'max_depth': 27, 'n_estimators': 246}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:41:58,584] Trial 88 finished with value: 0.7171743365875165 and parameters: {'learning_rate': 0.06222467452265752, 'min_child_samples': 141, 'max_depth': 26, 'n_estimators': 251}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:42:04,071] Trial 89 finished with value: 0.6987964658809064 and parameters: {'learning_rate': 0.0635679663444619, 'min_child_samples': 171, 'max_depth': 25, 'n_estimators': 268}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:42:12,010] Trial 90 finished with value: 0.7961403663395855 and parameters: {'learning_rate': 0.0775935787086413, 'min_child_samples': 15, 'max_depth': 27, 'n_estimators': 284}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:42:18,591] Trial 91 finished with value: 0.7978111176843165 and parameters: {'learning_rate': 0.05626134637541125, 'min_child_samples': 10, 'max_depth': 28, 'n_estimators': 226}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:42:24,834] Trial 92 finished with value: 0.796140383776994 and parameters: {'learning_rate': 0.06848962497150583, 'min_child_samples': 20, 'max_depth': 30, 'n_estimators': 213}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:42:31,736] Trial 93 finished with value: 0.797606528057962 and parameters: {'learning_rate': 0.05883245970434675, 'min_child_samples': 14, 'max_depth': 29, 'n_estimators': 241}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:42:37,022] Trial 94 finished with value: 0.7960380750138899 and parameters: {'learning_rate': 0.052422348856848704, 'min_child_samples': 23, 'max_depth': 28, 'n_estimators': 205}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:42:43,363] Trial 95 finished with value: 0.792798971762056 and parameters: {'learning_rate': 0.0606663681040094, 'min_child_samples': 29, 'max_depth': 27, 'n_estimators': 231}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:42:50,796] Trial 96 finished with value: 0.7982884527918573 and parameters: {'learning_rate': 0.07002456823944916, 'min_child_samples': 10, 'max_depth': 30, 'n_estimators': 259}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:42:56,452] Trial 97 finished with value: 0.7314263839206224 and parameters: {'learning_rate': 0.07067084584451115, 'min_child_samples': 122, 'max_depth': 30, 'n_estimators': 258}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:42:59,777] Trial 98 finished with value: 0.7950152419690131 and parameters: {'learning_rate': 0.06662887413461525, 'min_child_samples': 18, 'max_depth': 29, 'n_estimators': 123}. Best is trial 65 with value: 0.7989362978545961.
# [I 2025-06-05 23:43:08,145] Trial 99 finished with value: 0.7912646995261099 and parameters: {'learning_rate': 0.07317128270882119, 'min_child_samples': 25, 'max_depth': 30, 'n_estimators': 295}. Best is trial 65 with value: 0.7989362978545961.

# %%
best_params = study.best_params
best_params
# Out:
# {'learning_rate': 0.06747064968662127,
#  'min_child_samples': 10,
#  'max_depth': 30,
#  'n_estimators': 240}

# %%
best_model = LGBMClassifier(
    objective="multiclass",
    num_class=3,
    metric="multi_logloss",
    is_unbalance=True,
    class_weight="balanced",
    learning_rate=best_params["learning_rate"],
    max_depth=best_params["max_depth"],
    n_estimators=best_params["n_estimators"],
    min_child_samples=best_params["min_child_samples"],
    random_state=42,
    n_jobs=-1
)

# %%
best_model.fit(X_train_vectorized, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031495 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5012
# [LightGBM] [Info] Number of data points in the train set: 29329, number of used features: 995
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# LGBMClassifier(class_weight='balanced', is_unbalance=True,
#                learning_rate=0.06747064968662127, max_depth=30,
#                metric='multi_logloss', min_child_samples=10, n_estimators=240,
#                n_jobs=-1, num_class=3, objective='multiclass', random_state=42)

# %%
y_train_pred = best_model.predict(X_train_vectorized)
accuracy_train = accuracy_score(
    y_true=y_train,
    y_pred=y_train_pred
)
accuracy_train
# Out:
# d:\projects\DSMP2_p2\youtube-comments-analyzer\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 0.8439428551945174

# %%
classification_report_train = classification_report(
    y_true=y_train,
    y_pred=y_train_pred
)
print(classification_report_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.97      0.86     10115
#            1       0.94      0.80      0.86     12616
#            2       0.81      0.74      0.77      6598
#
#     accuracy                           0.84     29329
#    macro avg       0.84      0.84      0.83     29329
# weighted avg       0.86      0.84      0.84     29329

# %%
y_test_pred = best_model.predict(X_test_vectorized)
accuracy_test = accuracy_score(
    y_true=y_test,
    y_pred=y_test_pred
)
accuracy_test
# Out:
# d:\projects\DSMP2_p2\youtube-comments-analyzer\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 0.7940815491613256

# %%
classification_report_test = classification_report(
    y_true=y_test,
    y_pred=y_test_pred
)
print(classification_report_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.96      0.85      2529
#            1       0.89      0.75      0.81      3154
#            2       0.71      0.62      0.66      1650
#
#     accuracy                           0.79      7333
#    macro avg       0.78      0.78      0.77      7333
# weighted avg       0.80      0.79      0.79      7333

# %%
log_to_mlflow(
    model_name="LightGBM",
    improvement_technique="class_weights",
    model=best_model,
    X_train=X_train_vectorized,
    X_test=X_test_vectorized,
    y_train=y_train,
    y_test=y_test,
    best_params=best_params
)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021085 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5012
# [LightGBM] [Info] Number of data points in the train set: 29329, number of used features: 995
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# d:\projects\DSMP2_p2\youtube-comments-analyzer\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 2025/06/05 23:45:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run LightGBM_class_weights at: https://dagshub.com/SushrutGaikwad/youtube-comments-analyzer.mlflow/#/experiments/7/runs/ed6df19c7c974906b08fcb0f1d6b8fd6
# 🧪 View experiment at: https://dagshub.com/SushrutGaikwad/youtube-comments-analyzer.mlflow/#/experiments/7
